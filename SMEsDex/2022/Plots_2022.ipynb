# %% [markdown]
# # Primero conectamos con el script que posee los objetos (indicadores)

# %%
from Indicators_2022 import *
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore", message="FigureCanvasAgg is non-interactive, and thus cannot be shown")
# Out:
# ['DIRECTORIO', 'SECUENCIA_P', 'SECUENCIA_ENCUESTA', 'P3002', 'P3003_1', 'P3003_2', 'P3003_3', 'P3003_4', 'P3003_5', 'P3003_6']
# ['P3003_7', 'P3003_8', 'P3004', 'P3005_1', 'P3005_2', 'P3005_3', 'P3005_4', 'P3005_5', 'P3005_6', 'P3005_7']
# ['P3005_8', 'P3006', 'P3007_1', 'P3007_2', 'P3007_3', 'P3007_4', 'P3007_5', 'P3007_6', 'P3007_7', 'P3007_8']
# ['P3008', 'P3009_1', 'P3009_2', 'P3009_3', 'P3009_4', 'P3009_5', 'P3009_6', 'P3009_7', 'P3009_8', 'P3010']
# ['P3011_1', 'P3011_2', 'P3011_3', 'P3011_4', 'P3011_5', 'P3011_6', 'P3011_7', 'P3011_8', 'P3012', 'P3013_1']
# ['P3013_2', 'P3013_3', 'P3013_4', 'P3013_5', 'P3013_6', 'P3013_7', 'P3013_8', 'P3022', 'P3015_1', 'P3015_2']
# ['P3015_3', 'P3015_4', 'P3015_5', 'P3015_6', 'P3015_7', 'P3015_8', 'P3016', 'P3021_1', 'P3021_2', 'P3021_3']
# ['P3021_4', 'P3021_5', 'P3021_6', 'P3021_7', 'P3021_8', 'P4003', 'CLASE_TE', 'COD_DEPTO', 'AREA', 'F_EXP']
# ['P3057', 'P3058', 'P3059', 'P3060', 'P3061', 'P3062', 'P4002', 'P3063', 'P3064', 'P3065']
# ...

# %% [markdown]
# # Catalogo de Plots

# %% [markdown]
# # Indicadores principales

# %%
#Participación de valor agregado por actividad económica  (porcentaje). participacion_valor_agregado_por_grupo_plot
participacion_valor_agregado_por_grupo_2022_plot, ax = plt.subplots(figsize=(10, 8))
participacion_valor_agregado_por_grupo_2022 = participacion_valor_agregado_por_grupo_2022.sort_values(by='Porcentaje', ascending=True)
participacion_valor_agregado_por_grupo_2022.plot(
    kind='barh', 
    x='Nombre_Grupo', 
    y='Porcentaje', 
    color=['#2596be', '#8fcae2'], 
    width=0.4,  # Grosor de las barras reducido
    ax=ax,
    edgecolor='none'  # Desactivar bordes de las barras
)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['bottom'].set_visible(True)
ax.set_title('Distribución de valor agregado por actividad económica', fontsize=14)
ax.set_xlabel('Porcentaje (%)', fontsize=12)
ax.set_ylabel('')
for p in ax.patches:
    x = p.get_width()
    y = p.get_y() + p.get_height() / 2
    if x > 0:
        ax.text(x + 0.5, y, f'{x:,.1f}%', ha='left', va='center', fontsize=10, color='black')
plt.grid(False)
plt.tight_layout()
participacion_valor_agregado_por_grupo_2022_plot.show()

# %%
#Distribución de micro negocios según actividad económica (porcentaje). micronegocios_por_grupo_plot
micronegocios_por_grupo_2022 = micronegocios_por_grupo_2022.sort_values(by='Porcentaje', ascending=True)
micronegocios_por_grupo_2022_plot, ax = plt.subplots(figsize=(10, 8))
micronegocios_por_grupo_2022.plot(
    kind='barh', 
    x='Nombre_Grupo', 
    y='Porcentaje', 
    color=['#2596be', '#8fcae2'], 
    width=0.4,  # Grosor de las barras reducido
    ax=ax,
    edgecolor='none'  # Desactivar bordes de las barras
)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['bottom'].set_visible(True)
ax.set_title('Distribución de micro negocios según actividad económica', fontsize=14)
ax.set_xlabel('Porcentaje (%)', fontsize=12)
ax.set_ylabel('')
for p in ax.patches:
    x = p.get_width()
    y = p.get_y() + p.get_height() / 2
    if x > 0:
        ax.text(x + 0.5, y, f'{x:,.1f}%', ha='left', va='center', fontsize=10, color='black')
plt.grid(False)
plt.tight_layout()
micronegocios_por_grupo_2022_plot.show()

# %% [markdown]
# # Resultados total nacional - cabeceras municipales - centros poblados y rural disperso

# %%
#Micronegocios según situación en el empleo del propietario(a). micronegocios_segun_situacion_empleo_propietario_plot
micronegocios_segun_situacion_empleo_propietario_2022_plot, ax = plt.subplots(figsize=(10, 8))
micronegocios_segun_situacion_empleo_propietario_2022[['%_Propietarios', '%_Trabajadores']].plot(
    kind='bar', 
    color=['#2596be', '#8fcae2'], 
    width=0.4,  # Grosor de las barras reducido
    ax=ax,
    edgecolor='none'  # Desactivar bordes de las barras
)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['bottom'].set_visible(True)
ax.set_title('Micronegocios según situación en el empleo del propietario(a)', fontsize=14)
ax.set_xlabel('Área geográfica', fontsize=12)
ax.set_ylabel('Porcentaje (%)', fontsize=12)
ax.set_xticklabels(micronegocios_segun_situacion_empleo_propietario_2022.index, rotation=0, ha='center')
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.text(p.get_x() + p.get_width() / 2., height + 0.5, f'{height:,.1f}%', 
                ha='center', va='bottom', fontsize=10, color='black')
plt.grid(False)
plt.tight_layout()
micronegocios_segun_situacion_empleo_propietario_2022_plot.show()

# %%
#Propietarios de micronegocios según sexo (porcentaje). propietarios_sex_plot
propietarios_sex_2022_plot, ax = plt.subplots(figsize=(10, 8))
propietarios_sex_2022[['Hombres', 'Mujeres']].plot(
    kind='bar',
    color=['#2596be', '#8fcae2'],
    width=0.4,  # Grosor de las barras reducido
    ax=ax,
    edgecolor='none'  # Desactivar bordes de las barras
)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['bottom'].set_visible(True)
ax.set_title('Propietarios de Micronegocios según Sexo (Porcentaje)', fontsize=14)
ax.set_xlabel('Área Geográfica', fontsize=12)
ax.set_ylabel('Porcentaje (%)', fontsize=12)
ax.set_xticklabels(propietarios_sex_2022.index, rotation=0, ha='center')
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.text(p.get_x() + p.get_width() / 2., height + 0.5, f'{height:,.1f}%',
                ha='center', va='bottom', fontsize=10, color='black')
plt.grid(False)
plt.tight_layout()
propietarios_sex_2022_plot.show()

# %%
#Micronegocios según rangos de personal ocupado (porcentaje). rangos_personal_ocup_plot
rangos_personal_ocup_2022_plot, ax = plt.subplots(figsize=(10, 8))
rangos_personal_ocup_2022[['1 persona', '2-3 personas', '4-9 personas']].plot(
    kind='bar',
    color=[ '#8fcae2', '#2596be','#12455c'],
    width=0.4,  # Grosor de las barras reducido
    ax=ax,
    edgecolor='none'  # Desactivar bordes de las barras
)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['bottom'].set_visible(True)
ax.set_title('Micronegocios según Rangos de Personal Ocupado (Porcentaje)', fontsize=14)
ax.set_xlabel('Área Geográfica', fontsize=12)
ax.set_ylabel('Porcentaje (%)', fontsize=12)
ax.set_xticklabels(rangos_personal_ocup_2022.index, rotation=0, ha='center')
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.text(p.get_x() + p.get_width() / 2., height + 0.5, f'{height:,.1f}%',
                ha='center', va='bottom', fontsize=10, color='black')
plt.grid(False)
plt.tight_layout()
rangos_personal_ocup_2022_plot.show()
print("NO empleamos los datos expandidos con proyecciones con base en los resultados del CNPV 2018")
# Out:
# NO empleamos los datos expandidos con proyecciones con base en los resultados del CNPV 2018

# %% [markdown]
# # Formalidad

# %%
#Distribución según tenencia de RUT (porcentaje). formalidad_rut_tipo_plot
formalidad_rut_tipo_2022_plot, ax = plt.subplots(figsize=(10, 8))
formalidad_rut_tipo_2022[['Porcentaje con RUT', 'Porcentaje sin RUT']].plot(
    kind='bar',
    color=['#2596be', '#8fcae2'],  # Colores para las barras
    width=0.4,  # Grosor de las barras reducido
    ax=ax,
    edgecolor='none'  # Desactivar bordes de las barras
)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['bottom'].set_visible(True)
ax.set_title('Distribución según Tenencia de RUT (Porcentaje)', fontsize=14)
ax.set_xlabel('Área Geográfica', fontsize=12)
ax.set_ylabel('Porcentaje (%)', fontsize=12)
ax.set_xticklabels(formalidad_rut_tipo_2022.index, rotation=0, ha='center')
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.text(p.get_x() + p.get_width() / 2., height + 0.5, f'{height:,.1f}%',
                ha='center', va='bottom', fontsize=10, color='black')
plt.grid(False)
plt.tight_layout()
formalidad_rut_tipo_2022_plot.show()

# %%
#Distribución según tenencia de registro en Cámara de Comercio (porcentaje). formalidad_rcc_tipo_plot
formalidad_rcc_tipo_2022_plot, ax = plt.subplots(figsize=(10, 8))
formalidad_rcc_tipo_2022[['Porcentaje con Cámara de Comercio', 'Porcentaje sin Cámara de Comercio']].plot(
    kind='bar',
    color=['#2596be', '#8fcae2'],  # Colores para las barras
    width=0.4,  # Grosor de las barras reducido
    ax=ax,
    edgecolor='none'  # Desactivar bordes de las barras
)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['bottom'].set_visible(True)
ax.set_title('Distribución según Tenencia de Registro en Cámara de Comercio (Porcentaje)', fontsize=14)
ax.set_xlabel('Área Geográfica', fontsize=12)
ax.set_ylabel('Porcentaje (%)', fontsize=12)
ax.set_xticklabels(formalidad_rcc_tipo_2022.index, rotation=0, ha='center')
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.text(p.get_x() + p.get_width() / 2., height + 0.5, f'{height:,.1f}%',
                ha='center', va='bottom', fontsize=10, color='black')
plt.grid(False)
plt.tight_layout()
formalidad_rcc_tipo_2022_plot.show()

# %%
#Distribución de propietarios según aportes a salud y pensión (porcentaje). prop_aport_salud_pens_tipo_plot
prop_aport_salud_pens_tipo_2022 = prop_aport_salud_pens_tipo_2022.sort_values(by= "Porcentaje que solo pagó salud",ascending=False)
prop_aport_salud_pens_tipo_2022_plot, ax = plt.subplots(figsize=(10, 8))
prop_aport_salud_pens_tipo_2022[['Porcentaje que no pagó', 'Porcentaje que pagó salud y pensión', 'Porcentaje que solo pagó salud', 'Porcentaje que solo pagó pensión']].plot(
    kind='bar',
    color=['#8fcae2', '#2596be', '#12455c', '#164458'],  # Colores para las barras
    width=0.4,  # Grosor de las barras reducido
    ax=ax,
    edgecolor='none'  # Desactivar bordes de las barras
)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['bottom'].set_visible(True)
ax.set_title('Distribución de Propietarios según Aportes a Salud y Pensión (Porcentaje)', fontsize=14)
ax.set_xlabel('Área Geográfica', fontsize=12)
ax.set_ylabel('Porcentaje (%)', fontsize=12)
ax.set_xticklabels(prop_aport_salud_pens_tipo_2022.index, rotation=0, ha='center')
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.text(p.get_x() + p.get_width() / 2., height + 0.5, f'{height:,.1f}%',
                ha='center', va='bottom', fontsize=10, color='black')
plt.grid(False)
plt.tight_layout()
prop_aport_salud_pens_tipo_2022_plot.show()

# %%
#Distribución de propietarios según aportes a ARL (porcentaje). prop_aport_arl_tipo_plot
prop_aport_arl_tipo_2022_plot, ax = plt.subplots(figsize=(10, 8))
prop_aport_arl_tipo_2022[["Porcentaje que no pagó ARL", 'Porcentaje que pagó ARL']].plot(
    kind='bar',
    color=['#2596be', '#8fcae2'],  # Colores para las barras
    width=0.4,  # Grosor de las barras reducido
    ax=ax,
    edgecolor='none'  # Desactivar bordes de las barras
)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['bottom'].set_visible(True)
ax.set_title('Distribución de Propietarios según Aportes a ARL (Porcentaje)', fontsize=14)
ax.set_xlabel('Área Geográfica', fontsize=12)
ax.set_ylabel('Porcentaje (%)', fontsize=12)
ax.set_xticklabels(prop_aport_arl_tipo_2022.index, rotation=0, ha='center')
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.text(p.get_x() + p.get_width() / 2., height + 0.5, f'{height:,.1f}%',
                ha='center', va='bottom', fontsize=10, color='black')
plt.grid(False)
plt.tight_layout()
prop_aport_arl_tipo_2022_plot.show()

# %%
#Distribución de la cantidad de micronegocios según solicitud o renovación del registro ante Cámara de Comercio durante el año 2022 (porcentaje). 
#solicitud_rcc_tipo_plot
solicitud_rcc_tipo_2022_plot, ax = plt.subplots(figsize=(10, 8))
solicitud_rcc_tipo_2022[["No Renovó (%)", "Renovó (%)"]].plot(
    kind='bar',
    color=['#2596be', '#8fcae2'],  # Colores de las barras
    width=0.4,  # Grosor de las barras
    ax=ax,
    edgecolor='none'  # Sin bordes en las barras
)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['bottom'].set_visible(True)
ax.set_title('Distribución de la cantidad de micronegocios según solicitud o renovación del registro\nante Cámara de Comercio durante el año 2022 (porcentaje)', fontsize=14)
ax.set_xlabel('Área Geográfica', fontsize=12)
ax.set_ylabel('Porcentaje (%)', fontsize=12)
ax.set_xticklabels(solicitud_rcc_tipo_2022.index, rotation=0, ha='center')
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.text(p.get_x() + p.get_width() / 2., height + 0.5, f'{height:,.1f}%',
                ha='center', va='bottom', fontsize=10, color='black')
plt.grid(False)
plt.tight_layout()
solicitud_rcc_tipo_2022_plot.show()

# %%
#Distribución de micronegocios según tipo de registro contable (porcentaje).
#registro_contable_tipo_plot
registro_contable_tipo_2022_plot, ax = plt.subplots(figsize=(12, 8))
registro_contable_tipo_2022.plot(
    kind='bar',
    color=['#000304',  '#12455c', '#8fcae2', '#2596be',   '#568a9c'],  # Colores para cada categoría
    width=0.7,  # Grosor de las barras
    ax=ax,
    edgecolor='none'  # Sin bordes en las barras
)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['bottom'].set_visible(True)
ax.set_title('Distribución de Micronegocios según Tipo de Registro Contable (Porcentaje)', fontsize=14)
ax.set_xlabel('Área Geográfica', fontsize=12)
ax.set_ylabel('Porcentaje (%)', fontsize=12)
ax.set_xticklabels(registro_contable_tipo_2022.index, rotation=0, ha='center')
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.text(p.get_x() + p.get_width() / 2., height + 0.5, f'{height:,.1f}%',
                ha='center', va='bottom', fontsize=10, color='black')
plt.grid(False)
plt.tight_layout()
registro_contable_tipo_2022_plot.show()

# %%
#Micronegocios según declaración de impuestos renta (porcentaje). 
#declaracion_tx_plot
declaracion_tx_2022_plot, ax = plt.subplots(figsize=(8, 6))
declaracion_tx_2022.plot(
    kind='bar',
    color=['#2596be'],  # Color para la barra
    width=0.5,  # Grosor de las barras
    ax=ax,
    legend=False,
    edgecolor='none'  # Sin bordes en las barras
)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['bottom'].set_visible(True)
ax.set_title('Distribución de Micronegocios según Declaración de Renta (Porcentaje)', fontsize=14)
ax.set_xlabel('Declaración de Impuestos', fontsize=12)
ax.set_ylabel('Porcentaje (%)', fontsize=12)
ax.set_xticklabels(declaracion_tx_2022.index, rotation=0, ha='center')
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.text(p.get_x() + p.get_width() / 2., height + 0.5, f'{height:,.1f}%',
                ha='center', va='bottom', fontsize=10, color='black')
plt.grid(False)
plt.tight_layout()
declaracion_tx_2022_plot.show()

# %%
#Micronegocios según declaración de impuestos iva (porcentaje). 
#declaracion_iva_plot
declaracion_iva_2022_plot, ax = plt.subplots(figsize=(8, 6))
declaracion_iva_2022.plot(
    kind='bar',
    color=['#2596be'],  # Color para la barra
    width=0.5,  # Grosor de las barras
    ax=ax,
    legend=False,
    edgecolor='none'  # Sin bordes en las barras
)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['bottom'].set_visible(True)
ax.set_title('Distribución de Micronegocios según Declaración de IVA (Porcentaje)', fontsize=14)
ax.set_xlabel('Declaración de IVA', fontsize=12)
ax.set_ylabel('Porcentaje (%)', fontsize=12)
ax.set_xticklabels(declaracion_iva_2022.index, rotation=0, ha='center')
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.text(p.get_x() + p.get_width() / 2., height + 0.5, f'{height:,.1f}%',
                ha='center', va='bottom', fontsize=10, color='black')
plt.grid(False)
plt.tight_layout()
declaracion_iva_2022_plot.show()

# %%
#Micronegocios según declaración de impuestos ica (porcentaje). 
#declaracion_ica_plot
declaracion_ica_2022_plot, ax = plt.subplots(figsize=(8, 6))
declaracion_ica_2022.plot(
    kind='bar',
    color=['#2596be'],  # Color para la barra
    width=0.5,  # Grosor de las barras
    ax=ax,
    legend=False,
    edgecolor='none'  # Sin bordes en las barras
)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['bottom'].set_visible(True)
ax.set_title('Distribución de Micronegocios según Declaración de ICA (Porcentaje)', fontsize=14)
ax.set_xlabel('Declaración de ICA', fontsize=12)
ax.set_ylabel('Porcentaje (%)', fontsize=12)
ax.set_xticklabels(declaracion_ica_2022.index, rotation=0, ha='center')
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.text(p.get_x() + p.get_width() / 2., height + 0.5, f'{height:,.1f}%',
                ha='center', va='bottom', fontsize=10, color='black')
plt.grid(False)
plt.tight_layout()
declaracion_ica_2022_plot.show()

# %% [markdown]
# # Emprendimiento

# %%
#Distribución de micronegocios según quién creó o constituyó el negocio (porcentaje). 
#const_micron_tipo_plot
const_micron_tipo_2022_plot, ax = plt.subplots(figsize=(10, 8))
const_micron_tipo_2022.plot(
    kind='bar',
    color=['#2596be', '#8fcae2', '#12455c'],  # Colores para cada columna
    width=0.7,  # Grosor de las barras
    ax=ax,
    edgecolor='none'  # Sin bordes en las barras
)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['bottom'].set_visible(True)
ax.set_title('Distribución de Micronegocios según Quién Creó o Constituyó el Negocio (Porcentaje)', fontsize=14)
ax.set_xlabel('Constitución del Negocio', fontsize=12)
ax.set_ylabel('Porcentaje (%)', fontsize=12)
ax.set_xticklabels(const_micron_tipo_2022.index, rotation=0, ha='center')
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.text(p.get_x() + p.get_width() / 2., height + 0.5, f'{height:,.1f}%',
                ha='center', va='bottom', fontsize=10, color='black')
plt.grid(False)
plt.tight_layout()
const_micron_tipo_2022_plot.show()

# %%
#Distribución de micronegocios según motivo principal para la creación o constitución del negocio (porcentaje). 
#motivo_const_tipo_plot
motivo_const_tipo_2022_plot, ax = plt.subplots(figsize=(14, 8))
motivo_const_tipo_2022.plot(
    kind='bar',
    ax=ax,
    color=['#2596be', '#8fcae2', '#12455c'],  # Colores para las barras
    width=0.7,  # Ajustar el grosor de las barras
    edgecolor='none'  # Desactivar bordes de las barras
)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['bottom'].set_visible(True)
ax.set_title('Distribución de Motivos por Área Geográfica (Porcentaje)', fontsize=16)
ax.set_xlabel('Motivo', fontsize=14)
ax.set_ylabel('Porcentaje (%)', fontsize=14)
ax.set_xticks(range(len(motivo_const_tipo_2022.index)))
ax.set_xticklabels(motivo_const_tipo_2022.index, rotation=45, ha='right')
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.text(p.get_x() + p.get_width() / 2., height + 0.5, f'{height:.1f}%',
                ha='center', va='bottom', fontsize=10, color='black')
plt.grid(False)
plt.tight_layout()
motivo_const_tipo_2022_plot.show()

# %%
#Distribución de micronegocios según tiempo de funcionamiento (porcentaje). 
#micron_t_tipo_plot
micron_t_tipo_2022_plot, ax = plt.subplots(figsize=(14, 8))
micron_t_tipo_2022.plot(
    kind='bar',
    ax=ax,
    color=['#2596be', '#8fcae2', '#12455c'],  # Colores para las barras
    width=0.7,  # Ajustar el grosor de las barras
    edgecolor='none'  # Desactivar bordes de las barras
)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['bottom'].set_visible(True)
ax.set_title('Distribución de Micronegocios según Tiempo de Funcionamiento (Porcentaje)', fontsize=16)
ax.set_xlabel('Tiempo de Funcionamiento', fontsize=14)
ax.set_ylabel('Porcentaje (%)', fontsize=14)
ax.set_xticks(range(len(micron_t_tipo_2022.index)))
ax.set_xticklabels(micron_t_tipo_2022.index, rotation=45, ha='right')
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.text(p.get_x() + p.get_width() / 2., height + 0.5, f'{height:.1f}%',
                ha='center', va='bottom', fontsize=10, color='black')
plt.grid(False)
plt.tight_layout()
micron_t_tipo_2022_plot.show()

# %%
#Distribución de micronegocios según mayor fuente de recursos para la creación o constitución del negocio  (porcentaje). 
#micron_financ_plot
micron_financ_2022_plot, ax = plt.subplots(figsize=(14, 8))
micron_financ_2022.plot(
    kind='bar',
    ax=ax,
    color=['#2596be', '#8fcae2', '#12455c'],  # Colores para las barras
    width=0.7,  # Ajustar el grosor de las barras
    edgecolor='none'  # Desactivar bordes de las barras
)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['bottom'].set_visible(True)
ax.set_title('Distribución de Micronegocios según Fuente de Recursos para la Creación (Porcentaje)', fontsize=16)
ax.set_xlabel('Fuente de Recursos', fontsize=14)
ax.set_ylabel('Porcentaje (%)', fontsize=14)
ax.set_xticks(range(len(micron_financ_2022.index)))
ax.set_xticklabels(micron_financ_2022.index, rotation=45, ha='right')
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.text(p.get_x() + p.get_width() / 2., height + 0.5, f'{height:.1f}%',
                ha='center', va='bottom', fontsize=10, color='black')
plt.grid(False)
plt.tight_layout()
micron_financ_2022_plot.show()

# %% [markdown]
# # Sitio o Ubicación

# %%
#Distribución de micronegocios según sitio o ubicación (porcentaje). 
#emicron_ubic_tipo_plot
emicron_ubic_tipo_2022_plot, ax = plt.subplots(figsize=(10, 8))
emicron_ubic_tipo_2022.plot(
    kind='bar',
    color=['#2596be', '#8fcae2', '#12455c'],  # Colores para cada columna
    width=0.7,  # Grosor de las barras
    ax=ax,
    edgecolor='none'  # Sin bordes en las barras
)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['bottom'].set_visible(True)
ax.set_title('Distribución de Micronegocios según Sitio o Ubicación (Porcentaje)', fontsize=14)
ax.set_xlabel('Ubicación del Negocio', fontsize=12)
ax.set_ylabel('Porcentaje (%)', fontsize=12)
ax.set_xticklabels(emicron_ubic_tipo_2022.index, rotation=45, ha='right')  # Inclinación de 45 grados
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.text(p.get_x() + p.get_width() / 2., height + 0.5, f'{height:,.1f}%',
                ha='center', va='bottom', fontsize=10, color='black')
plt.grid(False)
plt.tight_layout()
emicron_ubic_tipo_2022_plot.show()

# %% [markdown]
# # Tecnologias de la Información y la Comunicación

# %%
#Distribución de micronegocios según uso de dispositivos electrónicos (porcentaje). 
#uso_electr_tipo_plot
uso_electr_tipo_2022_plot, ax = plt.subplots(figsize=(10, 8))
uso_electr_tipo_2022.plot(
    kind='bar',
    color=['#2596be', '#8fcae2', '#12455c'],  # Colores para las barras
    width=0.4,  # Grosor de las barras reducido
    ax=ax,
    edgecolor='none'  # Desactivar bordes de las barras
)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['bottom'].set_visible(True)
ax.set_title('Distribución de Micronegocios según Uso de Dispositivos Electronicos (Porcentaje)', fontsize=14)
ax.set_xlabel('Emplea Dispositivos Electronicos', fontsize=12)
ax.set_ylabel('Porcentaje (%)', fontsize=12)
ax.set_xticklabels(uso_electr_tipo_2022.index, rotation=0, ha='center')
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.text(p.get_x() + p.get_width() / 2., height + 0.5, f'{height:,.1f}%',
                ha='center', va='bottom', fontsize=10, color='black')
plt.grid(False)
plt.tight_layout()
uso_electr_tipo_2022_plot.show()

# %%
#Distribución de micronegocios según uso del teléfono celular (porcentaje). 
#uso_cel_tipo_plot
uso_cel_tipo_2022_plot, ax = plt.subplots(figsize=(10, 8))
uso_cel_tipo_2022.plot(
    kind='bar',
    color=['#2596be', '#8fcae2', '#12455c'],  # Colores para las barras
    width=0.4,  # Grosor de las barras reducido
    ax=ax,
    edgecolor='none'  # Desactivar bordes de las barras
)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['bottom'].set_visible(True)
ax.set_title('Distribución de Micronegocios según Uso de Teléfono Celular (Porcentaje)', fontsize=14)
ax.set_xlabel('Uso de Teléfono Celular', fontsize=12)
ax.set_ylabel('Porcentaje (%)', fontsize=12)
ax.set_xticklabels(uso_cel_tipo_2022.index, rotation=0, ha='center')
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.text(p.get_x() + p.get_width() / 2., height + 0.5, f'{height:,.1f}%',
                ha='center', va='bottom', fontsize=10, color='black')
plt.grid(False)
plt.tight_layout()
uso_cel_tipo_2022_plot.show()

# %%
#Distribución de micronegocios según uso del servicio de internet (porcentaje). 
#uso_internet_tipo_plot
uso_internet_tipo_2022_plot, ax = plt.subplots(figsize=(10, 8))
uso_internet_tipo_2022.plot(
    kind='bar',
    color=['#2596be', '#8fcae2', '#12455c'],  # Colores para las barras
    width=0.4,  # Grosor de las barras reducido
    ax=ax,
    edgecolor='none'  # Desactivar bordes de las barras
)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['bottom'].set_visible(True)
ax.set_title('Distribución de Micronegocios según Uso de Servicio de Internet (Porcentaje)', fontsize=14)
ax.set_xlabel('Uso de Internet', fontsize=12)
ax.set_ylabel('Porcentaje (%)', fontsize=12)
ax.set_xticklabels(uso_internet_tipo_2022.index, rotation=0, ha='center')
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.text(p.get_x() + p.get_width() / 2., height + 0.5, f'{height:,.1f}%',
                ha='center', va='bottom', fontsize=10, color='black')
plt.grid(False)
plt.tight_layout()
uso_internet_tipo_2022_plot.show()

# %% [markdown]
# # Ciudades principales y áreas metropolitanas

# %%
#Distribución del valor agregado por ciudad 24 Ciudades y áreas metropolitanas. 
#valor_agreg_ciudades_plot
valor_agreg_ciudades_2022_plot, ax = plt.subplots(figsize=(12, 8))
valor_agreg_ciudades_2022.plot(
    kind='bar',
    x='Área Metropolitana / Ciudad',
    y='Porcentaje del Valor Agregado Anual (%)',
    color='#2596be',  # Color de las barras
    ax=ax,
    edgecolor='none'  # Desactivar bordes de las barras
)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['bottom'].set_visible(True)
ax.set_title('Distribución del Valor Agregado Anual por Ciudad', fontsize=16)
ax.set_xlabel('Área Metropolitana / Ciudad', fontsize=12)
ax.set_ylabel('Porcentaje del Valor Agregado Anual (%)', fontsize=12)
ax.set_xticklabels(valor_agreg_ciudades_2022['Área Metropolitana / Ciudad'], rotation=45, ha='right')
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.text(p.get_x() + p.get_width() / 2., height + 0.5, f'{height:,.1f}%',
                ha='center', va='bottom', fontsize=10, color='black')
plt.grid(False)
plt.tight_layout()
valor_agreg_ciudades_2022_plot.show()

# %%
#Distribución de la cantidad de micronegocios según ciudad 24 Ciudades y áreas metropolitanas. 
#micron_ciudades_plot
micron_ciudades_2022_plot, ax = plt.subplots(figsize=(12, 8))
distribucion_df.plot(
    kind='bar',
    x='Ciudad',
    y='Distribucion de micronegocios %',
    color='#2596be',  # Color de las barras
    ax=ax,
    edgecolor='none'  # Desactivar bordes de las barras
)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['bottom'].set_visible(True)
ax.set_title('Distribución de Micronegocios por Ciudad', fontsize=16)
ax.set_xlabel('Ciudad', fontsize=12)
ax.set_ylabel('Distribución de Micronegocios (%)', fontsize=12)
ax.set_xticklabels(distribucion_df['Ciudad'], rotation=45, ha='right')
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.text(p.get_x() + p.get_width() / 2., height + 0.5, f'{height:,.1f}%',
                ha='center', va='bottom', fontsize=10, color='black')
plt.grid(False)
plt.tight_layout()
micron_ciudades_2022_plot.show()

# %%
#Distribución de micronegocios según situación en el empleo del propietario (porcentaje) 24 Ciudades y áreas metropolitanas.
#prop_situa_ciudades_plot
prop_situa_ciudades_2022_plot, ax = plt.subplots(figsize=(12, 8))
prop_situa_ciudades_2022.set_index('Ciudad').plot(
    kind='bar',
    ax=ax,
    color=['#2596be', '#8fcae2'],  # Colores para las barras
    width=0.8,  # Grosor de las barras
    edgecolor='none'  # Desactivar bordes de las barras
)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['bottom'].set_visible(True)
ax.set_title('Distribución de Micronegocios según Situación en el Empleo del Propietario', fontsize=16)
ax.set_xlabel('Ciudad', fontsize=12)
ax.set_ylabel('Porcentaje (%)', fontsize=12)
ax.set_xticklabels(prop_situa_ciudades_2022['Ciudad'], rotation=45, ha='right')
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.text(p.get_x() + p.get_width() / 2., height + 0.5, f'{height:,.1f}%',
                ha='center', va='bottom', fontsize=10, color='black')
plt.grid(False)
plt.tight_layout()
plt.legend(title='Situación en el Empleo', labels=['Patrón o empleador (%)', 'Trabajador por cuenta propia (%)'])
prop_situa_ciudades_2022_plot.show()

# %%
#Porcentaje de micronegocios que desarrollan actividades de servicios (porcentaje) 24 Ciudades y áreas metropolitanas.
#micron_serv_ciudades_plot
micron_serv_ciudades_2022_plot, ax = plt.subplots(figsize=(12, 8))
micron_serv_ciudades_2022.set_index('Ciudad').plot(
    kind='bar',
    ax=ax,
    color='#2596be',  # Color para las barras
    width=0.8,  # Grosor de las barras
    edgecolor='none'  # Desactivar bordes de las barras
)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['bottom'].set_visible(True)
ax.set_title('Porcentaje de Micronegocios que Desarrollan Actividades de Servicios', fontsize=16)
ax.set_xlabel('Ciudad', fontsize=12)
ax.set_ylabel('Porcentaje (%)', fontsize=12)
ax.set_xticklabels(micron_serv_ciudades_2022['Ciudad'], rotation=45, ha='right')
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.text(p.get_x() + p.get_width() / 2., height + 0.5, f'{height:,.1f}%',
                ha='center', va='bottom', fontsize=10, color='black')
plt.grid(False)
plt.tight_layout()
micron_serv_ciudades_2022_plot.show()

# %%
#Porcentaje de micronegocios que desarrollan actividades de comercio (porcentaje) 24 Ciudades y áreas metropolitanas.
#micron_comerc_ciudades_plot
micron_comerc_ciudades_2022_plot, ax = plt.subplots(figsize=(12, 8))
micron_comerc_ciudades_2022.set_index('Ciudad').plot(
    kind='bar',
    ax=ax,
    color='#2596be',  # Color para las barras
    width=0.8,  # Grosor de las barras
    edgecolor='none'  # Desactivar bordes de las barras
)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['bottom'].set_visible(True)
ax.set_title('Porcentaje de Micronegocios que Desarrollan Actividades de Comercio', fontsize=16)
ax.set_xlabel('Ciudad', fontsize=12)
ax.set_ylabel('Porcentaje (%)', fontsize=12)
ax.set_xticklabels(micron_comerc_ciudades_2022['Ciudad'], rotation=45, ha='right')
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.text(p.get_x() + p.get_width() / 2., height + 0.5, f'{height:,.1f}%',
                ha='center', va='bottom', fontsize=10, color='black')
plt.grid(False)
plt.tight_layout()
micron_comerc_ciudades_2022_plot.show()

# %%
#Porcentaje de micronegocios que desarrollan actividades de industria manufacturera (porcentaje) 24 Ciudades y áreas metropolitanas.
#micron_manuf_ciudades_plot
micron_manuf_ciudades_2022_plot, ax = plt.subplots(figsize=(12, 8))
micron_manuf_ciudades_2022.set_index('Ciudad').plot(
    kind='bar',
    ax=ax,
    color='#2596be',  # Color para las barras
    width=0.8,  # Grosor de las barras
    edgecolor='none'  # Desactivar bordes de las barras
)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['bottom'].set_visible(True)
ax.set_title('Porcentaje de Micronegocios que Desarrollan Actividades de Industria Manufacturera', fontsize=16)
ax.set_xlabel('Ciudad', fontsize=12)
ax.set_ylabel('Porcentaje (%)', fontsize=12)
ax.set_xticklabels(micron_manuf_ciudades_2022['Ciudad'], rotation=45, ha='right')
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.text(p.get_x() + p.get_width() / 2., height + 0.5, f'{height:,.1f}%',
                ha='center', va='bottom', fontsize=10, color='black')
plt.grid(False)
plt.tight_layout()
micron_manuf_ciudades_2022_plot.show()

# %%
# !jupyter nbconvert --to script Plots_2022.ipynb
# Out:
# [NbConvertApp] Converting notebook Plots_2022.ipynb to script
# [NbConvertApp] Writing 33229 bytes to Plots_2022.py
